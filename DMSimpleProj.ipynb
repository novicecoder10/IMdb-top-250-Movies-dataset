# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("sample_data/iMDbTop250Movies.csv",na_values='NA')
df.head
# Out:
# <bound method NDFrame.head of                     Title  year     Rating Run Time  imdb_rating  \
# 0       On the Waterfront  1954   Approved   1h 48m          8.1
# 1    My Father and My Son  2005  Not Rated   1h 52m          8.2
# 2       Avengers: Endgame  2019      PG-13    3h 1m          8.4
# 3                    1917  2019          R   1h 59m          8.2
# 4                  Snatch  2000          R   1h 42m          8.3
# ..                    ...   ...        ...      ...          ...
# 245         The Third Man  1949   Approved   1h 33m          8.1
# 246          A Separation  2011      PG-13    2h 3m          8.3
# 247        V for Vendetta  2005          R   2h 12m          8.2
# 248            Green Book  2018      PG-13   2h 10m          8.2
# 249           City Lights  1931          G   1h 27m          8.5
#
#                        Budget Gross_worldwide         Director  Metascore
# 0        $910,000 (estimated)             NaN       Elia Kazan       91.0
# ...

# %%
df.plot.hist()

# %%
df.boxplot(vert=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
df.describe(include='all')
df.plot()
df.plot(x='Title',y='imdb_rating')
df.plot(subplots=True, figsize=(8,8))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f95f367c3d0>,
# ...
#       dtype=object)

# %%
plt.plot(df.imdb_rating,color='blue')

# %%
plt.scatter(df.year,df.imdb_rating)
plt.xlabel("year")
plt.ylabel("Metascore")
plt.title('Scatter plot')
# Out:
# Text(0.5, 1.0, 'Scatter plot')

# %%
plt.hist(df.Metascore)
# Out:
# (array([ 6.,  8., 16., 17., 28., 24., 36., 35., 28., 30.]),
#  array([ 55. ,  59.5,  64. ,  68.5,  73. ,  77.5,  82. ,  86.5,  91. ,
#          95.5, 100. ]),
#  <a list of 10 Patch objects>)

# %%
plt.bar(df.Title,df.imdb_rating)
# Out:
# <BarContainer object of 250 artists>

# %%
import seaborn as sns
sns.relplot(data=df,x='year',y='imdb_rating')

# %%
sns.lmplot(data=df,x='year',y='imdb_rating',hue='Title')

# %%
sns.pairplot(data=df,hue="Rating")

# %%
sns.catplot(data=df,x='year',y='Metascore')
